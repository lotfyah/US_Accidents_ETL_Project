# %% [markdown]
# # Import dependencies

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# # Store CSV into DataFrame

# %%
accident_csv_file = "Resources/US_Accidents_June20.csv"
accident_data_df = pd.read_csv(accident_csv_file)
accident_data_df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %% [markdown]
# # state_df

# %%
state_csv_file = "Resources/state_csvData.csv"
state_df = pd.read_csv(state_csv_file)
state_df.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
# Rename columns to match accident df for future merging
state_df = state_df.drop(columns={"Abbrev"})
state_df = state_df.rename(columns={"State": "state_name",
                                   "Code": "State"})
state_df.head()
# Out:
#    state_name State
# 0     Alabama    AL
# 1      Alaska    AK
# 2     Arizona    AZ
# 3    Arkansas    AR
# 4  California    CA

# %% [markdown]
# # accident_df

# %%
# view data before transformation
accident_data_df.nunique()
# Out:
# ID                       3513617
# Source                         3
# TMC                           21
# Severity                       4
# Start_Time               3200042
# End_Time                 3246120
# Start_Lat                1124695
# Start_Lng                1113407
# End_Lat                   375074
# End_Lng                   383569
# Distance(mi)               13476
# Description              1780092
# Number                     40365
# Street                    176262
# Side                           3
# City                       11895
# County                      1724
# State                         49
# Zipcode                   418780
# Country                        1
# Timezone                       4
# Airport_Code                2001
# Weather_Timestamp         546086
# Temperature(F)               831
# Wind_Chill(F)                974
# Humidity(%)                  100
# Pressure(in)                1022
# Visibility(mi)                85
# Wind_Direction                24
# Wind_Speed(mph)              160
# Precipitation(in)            261
# Weather_Condition            127
# Amenity                        2
# Bump                           2
# Crossing                       2
# Give_Way                       2
# Junction                       2
# No_Exit                        2
# Railway                        2
# Roundabout                     2
# Station                        2
# Stop                           2
# Traffic_Calming                2
# Traffic_Signal                 2
# Turning_Loop                   1
# Sunrise_Sunset                 2
# Civil_Twilight                 2
# Nautical_Twilight              2
# Astronomical_Twilight          2
# dtype: int64

# %%
accident_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3513617 entries, 0 to 3513616
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int64
#  4   Start_Time             object
#  5   End_Time               object
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance(mi)           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
#  21  Airport_Code           object
#  22  Weather_Timestamp      object
#  23  Temperature(F)         float64
#  24  Wind_Chill(F)          float64
#  25  Humidity(%)            float64
#  26  Pressure(in)           float64
#  27  Visibility(mi)         float64
#  28  Wind_Direction         object
#  29  Wind_Speed(mph)        float64
#  30  Precipitation(in)      float64
#  31  Weather_Condition      object
#  32  Amenity                bool
#  33  Bump                   bool
#  34  Crossing               bool
#  35  Give_Way               bool
#  36  Junction               bool
#  37  No_Exit                bool
#  38  Railway                bool
#  39  Roundabout             bool
#  40  Station                bool
#  41  Stop                   bool
#  42  Traffic_Calming        bool
#  43  Traffic_Signal         bool
#  44  Turning_Loop           bool
#  45  Sunrise_Sunset         object
#  46  Civil_Twilight         object
#  47  Nautical_Twilight      object
#  48  Astronomical_Twilight  object
# dtypes: bool(13), float64(14), int64(1), object(21)
# memory usage: 1008.6+ MB

# %% [markdown]
# # Create new accident df

# %%
new_accident_data_df = accident_data_df[['ID', 'Start_Time', 'City', 'County', 'State', 'Zipcode', 'Timezone', 'Temperature(F)', 'Visibility(mi)', 'Weather_Condition']].copy()
new_accident_data_df.head()
# Out:
#     ID           Start_Time          City      County State     Zipcode  \
# 0  A-1  2016-02-08 05:46:00        Dayton  Montgomery    OH       45424
# 1  A-2  2016-02-08 06:07:59  Reynoldsburg    Franklin    OH  43068-3402
# 2  A-3  2016-02-08 06:49:27  Williamsburg    Clermont    OH       45176
# 3  A-4  2016-02-08 07:23:34        Dayton  Montgomery    OH       45417
# 4  A-5  2016-02-08 07:39:07        Dayton  Montgomery    OH       45459
#
#      Timezone  Temperature(F)  Visibility(mi) Weather_Condition
# 0  US/Eastern            36.9            10.0        Light Rain
# 1  US/Eastern            37.9            10.0        Light Rain
# 2  US/Eastern            36.0            10.0          Overcast
# 3  US/Eastern            35.1             9.0     Mostly Cloudy
# 4  US/Eastern            36.0             6.0     Mostly Cloudy

# %% [markdown]
# # merge state and accident df

# %%
# Merge accident_df with state_df to obtain state_name for future merging with population df
clean_accident_data_df = pd.merge(new_accident_data_df, state_df, on= "State")
clean_accident_data_df.head()
# Out:
#     ID           Start_Time          City      County State     Zipcode  \
# 0  A-1  2016-02-08 05:46:00        Dayton  Montgomery    OH       45424
# 1  A-2  2016-02-08 06:07:59  Reynoldsburg    Franklin    OH  43068-3402
# 2  A-3  2016-02-08 06:49:27  Williamsburg    Clermont    OH       45176
# 3  A-4  2016-02-08 07:23:34        Dayton  Montgomery    OH       45417
# 4  A-5  2016-02-08 07:39:07        Dayton  Montgomery    OH       45459
#
#      Timezone  Temperature(F)  Visibility(mi) Weather_Condition state_name
# 0  US/Eastern            36.9            10.0        Light Rain       Ohio
# 1  US/Eastern            37.9            10.0        Light Rain       Ohio
# 2  US/Eastern            36.0            10.0          Overcast       Ohio
# 3  US/Eastern            35.1             9.0     Mostly Cloudy       Ohio
# 4  US/Eastern            36.0             6.0     Mostly Cloudy       Ohio

# %%
# convert start_time from object to datetime 
clean_accident_data_df['Start_Time'] = pd.to_datetime(clean_accident_data_df['Start_Time'])
clean_accident_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3513617 entries, 0 to 3513616
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ID                 object
#  1   Start_Time         datetime64[ns]
#  2   City               object
#  3   County             object
#  4   State              object
#  5   Zipcode            object
#  6   Timezone           object
#  7   Temperature(F)     float64
#  8   Visibility(mi)     float64
#  9   Weather_Condition  object
#  10  state_name         object
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 321.7+ MB

# %%
clean_accident_data_df.nunique()
# Out:
# ID                   3513617
# Start_Time           3200042
# City                   11895
# County                  1724
# State                     49
# Zipcode               418780
# Timezone                   4
# Temperature(F)           831
# Visibility(mi)            85
# Weather_Condition        127
# state_name                49
# dtype: int64

# %%
# Limit data from 2016-2020 to 2016 only
clean_accident_data_df = clean_accident_data_df[(clean_accident_data_df['Start_Time']>= "2016-01-01") & 
                                            (clean_accident_data_df['Start_Time']<= "2017-01-01")]
clean_accident_data_df.nunique()
# Out:
# ID                   410593
# Start_Time           374315
# City                   6862
# County                 1326
# State                    49
# Zipcode               69431
# Timezone                  4
# Temperature(F)          690
# Visibility(mi)           47
# Weather_Condition        62
# state_name               49
# dtype: int64

# %%
clean_accident_data_df.head()
# Out:
#     ID          Start_Time          City      County State     Zipcode  \
# 0  A-1 2016-02-08 05:46:00        Dayton  Montgomery    OH       45424
# 1  A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin    OH  43068-3402
# 2  A-3 2016-02-08 06:49:27  Williamsburg    Clermont    OH       45176
# 3  A-4 2016-02-08 07:23:34        Dayton  Montgomery    OH       45417
# 4  A-5 2016-02-08 07:39:07        Dayton  Montgomery    OH       45459
#
#      Timezone  Temperature(F)  Visibility(mi) Weather_Condition state_name
# 0  US/Eastern            36.9            10.0        Light Rain       Ohio
# 1  US/Eastern            37.9            10.0        Light Rain       Ohio
# 2  US/Eastern            36.0            10.0          Overcast       Ohio
# 3  US/Eastern            35.1             9.0     Mostly Cloudy       Ohio
# 4  US/Eastern            36.0             6.0     Mostly Cloudy       Ohio

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!! Didn't set ID as Index, ID is acting weird (ask team members) !!!!!!!!!!!!!!!!!!!!!!!!!!
clean_accident_data_df = clean_accident_data_df.sort_values(by='ID')
clean_accident_data_df.head()
# Out:
#               ID          Start_Time             City      County State  \
# 0            A-1 2016-02-08 05:46:00           Dayton  Montgomery    OH
# 9           A-10 2016-02-08 08:10:04      Westerville    Franklin    OH
# 99         A-100 2016-02-11 08:13:24           Dayton  Montgomery    OH
# 68791     A-1000 2016-06-23 10:31:12  El Dorado Hills   El Dorado    CA
# 167790  A-100000 2016-04-05 15:47:30             Brea      Orange    CA
#
#        Zipcode    Timezone  Temperature(F)  Visibility(mi) Weather_Condition  \
# 0        45424  US/Eastern            36.9            10.0        Light Rain
# 9        43081  US/Eastern            37.4             3.0        Light Rain
# 99       45410  US/Eastern             7.5            10.0  Scattered Clouds
# 68791    95762  US/Pacific            77.0            10.0             Clear
# 167790   92821  US/Pacific            84.9            10.0             Clear
#
#         state_name
# 0             Ohio
# 9             Ohio
# 99            Ohio
# 68791   California
# 167790  California

# %% [markdown]
# # Check to see if all 2016 data is present

# %%
# Sort by datetime
clean_accident_data_df = clean_accident_data_df.sort_values('Start_Time')
clean_accident_data_df.head()
# Out:
#               ID          Start_Time          City      County State  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin    OH
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery    OH
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery    OH
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin    OH
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton    OH
#
#           Zipcode    Timezone  Temperature(F)  Visibility(mi)  \
# 45629       43017  US/Eastern            42.1            10.0
# 0           45424  US/Eastern            36.9            10.0
# 45630       45424  US/Eastern            36.9            10.0
# 1      43068-3402  US/Eastern            37.9            10.0
# 45631       45203  US/Eastern            36.0            10.0
#
#       Weather_Condition state_name
# 45629        Light Rain       Ohio
# 0            Light Rain       Ohio
# 45630        Light Rain       Ohio
# 1            Light Rain       Ohio
# 45631          Overcast       Ohio

# %%
clean_accident_data_df.tail()
# Out:
#                 ID          Start_Time        City    County State  \
# 1591619  A-2521660 2016-12-31 23:42:02  Janesville      Rock    WI
# 1591618  A-2521658 2016-12-31 23:42:02  Janesville      Rock    WI
# 3215485  A-2494106 2016-12-31 23:48:21       Yukon  Canadian    OK
# 3500069  A-2521653 2016-12-31 23:49:59        Saco      York    ME
# 1443015  A-2494107 2016-12-31 23:58:25    Johnston      Polk    IA
#
#             Zipcode    Timezone  Temperature(F)  Visibility(mi)  \
# 1591619  53546-9128  US/Central            21.2            10.0
# 1591618       53546  US/Central            21.2            10.0
# 3215485       73099  US/Central            32.0            10.0
# 3500069       04072  US/Eastern            34.0             7.0
# 1443015       50131  US/Central            19.4            10.0
#
#         Weather_Condition state_name
# 1591619             Clear  Wisconsin
# 1591618             Clear  Wisconsin
# 3215485               NaN   Oklahoma
# 3500069        Light Rain      Maine
# 1443015             Clear       Iowa

# %%
clean_accident_data_df.count()
# Out:
# ID                   410593
# Start_Time           410593
# City                 410566
# County               410593
# State                410593
# Zipcode              410477
# Timezone             410464
# Temperature(F)       404137
# Visibility(mi)       401810
# Weather_Condition    402033
# state_name           410593
# dtype: int64

# %%
clean_accident_data_df.nunique()
# Out:
# ID                   410593
# Start_Time           374315
# City                   6862
# County                 1326
# State                    49
# Zipcode               69431
# Timezone                  4
# Temperature(F)          690
# Visibility(mi)           47
# Weather_Condition        62
# state_name               49
# dtype: int64

# %% [markdown]
# # Test to see if correct data is included

# %%
clean_accident_data_df.loc[clean_accident_data_df['ID']=='A-9152']
# Out:
#            ID          Start_Time       City       County State Zipcode  \
# 76943  A-9152 2016-12-30 23:42:34  Hollister  Santa Clara    CA   95023
#
#          Timezone  Temperature(F)  Visibility(mi) Weather_Condition  \
# 76943  US/Pacific            48.2            10.0          Overcast
#
#        state_name
# 76943  California

# %%
clean_accident_data_df.loc[clean_accident_data_df['ID']=='A-59918']
# Out:
#              ID          Start_Time            City          County State  \
# 127709  A-59918 2016-12-30 23:53:59  San Bernardino  San Bernardino    CA
#
#        Zipcode    Timezone  Temperature(F)  Visibility(mi) Weather_Condition  \
# 127709   92411  US/Pacific            53.6             2.0           Drizzle
#
#         state_name
# 127709  California

# %%
clean_accident_data_df.loc[clean_accident_data_df['ID']=='A-9153']
# Out:
#            ID          Start_Time      City       County State Zipcode  \
# 76944  A-9153 2016-12-31 01:23:30  San Jose  Santa Clara    CA   95112
#
#          Timezone  Temperature(F)  Visibility(mi) Weather_Condition  \
# 76944  US/Pacific            50.0            10.0          Overcast
#
#        state_name
# 76944  California

# %%
clean_accident_data_df.loc[clean_accident_data_df['Start_Time']=='2016-12-31 23:42:02']
# Out:
#                 ID          Start_Time        City County State     Zipcode  \
# 1591619  A-2521660 2016-12-31 23:42:02  Janesville   Rock    WI  53546-9128
# 1591618  A-2521658 2016-12-31 23:42:02  Janesville   Rock    WI       53546
#
#            Timezone  Temperature(F)  Visibility(mi) Weather_Condition  \
# 1591619  US/Central            21.2            10.0             Clear
# 1591618  US/Central            21.2            10.0             Clear
#
#         state_name
# 1591619  Wisconsin
# 1591618  Wisconsin

# %%
clean_accident_data_df['normalised_date'] = clean_accident_data_df['Start_Time'].dt.normalize()
clean_accident_data_df.head()
# Out:
#               ID          Start_Time          City      County State  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin    OH
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery    OH
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery    OH
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin    OH
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton    OH
#
#           Zipcode    Timezone  Temperature(F)  Visibility(mi)  \
# 45629       43017  US/Eastern            42.1            10.0
# 0           45424  US/Eastern            36.9            10.0
# 45630       45424  US/Eastern            36.9            10.0
# 1      43068-3402  US/Eastern            37.9            10.0
# 45631       45203  US/Eastern            36.0            10.0
#
#       Weather_Condition state_name normalised_date
# 45629        Light Rain       Ohio      2016-02-08
# 0            Light Rain       Ohio      2016-02-08
# 45630        Light Rain       Ohio      2016-02-08
# 1            Light Rain       Ohio      2016-02-08
# 45631          Overcast       Ohio      2016-02-08

# %%
clean_accident_data_df.loc[clean_accident_data_df['normalised_date']=='2016-01-01']
# Out:
# Empty DataFrame
# Columns: [ID, Start_Time, City, County, State, Zipcode, Timezone, Temperature(F), Visibility(mi), Weather_Condition, state_name, normalised_date]
# Index: []

# %% [markdown]
# # Reorganize df to look pretty

# %%
clean_accident_data_df = clean_accident_data_df[['ID', 'Start_Time', 'normalised_date', 'City', 'County', 'State', 'state_name', 'Zipcode', 'Timezone', 'Temperature(F)', 'Visibility(mi)', 'Weather_Condition']]
clean_accident_data_df.head()
# Out:
#               ID          Start_Time normalised_date          City  \
# 45629  A-2478859 2016-02-08 00:37:08      2016-02-08        Dublin
# 0            A-1 2016-02-08 05:46:00      2016-02-08        Dayton
# 45630  A-2478860 2016-02-08 05:56:20      2016-02-08        Dayton
# 1            A-2 2016-02-08 06:07:59      2016-02-08  Reynoldsburg
# 45631  A-2478861 2016-02-08 06:15:39      2016-02-08    Cincinnati
#
#            County State state_name     Zipcode    Timezone  Temperature(F)  \
# 45629    Franklin    OH       Ohio       43017  US/Eastern            42.1
# 0      Montgomery    OH       Ohio       45424  US/Eastern            36.9
# 45630  Montgomery    OH       Ohio       45424  US/Eastern            36.9
# 1        Franklin    OH       Ohio  43068-3402  US/Eastern            37.9
# 45631    Hamilton    OH       Ohio       45203  US/Eastern            36.0
#
#        Visibility(mi) Weather_Condition
# 45629            10.0        Light Rain
# 0                10.0        Light Rain
# 45630            10.0        Light Rain
# 1                10.0        Light Rain
# 45631            10.0          Overcast

# %%
# clean_accident_data_df.set_index("ID", inplace=True)

# %%
# clean_accident_data_df = clean_accident_data_df.rename(columns={"":""})
